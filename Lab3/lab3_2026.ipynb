# %% [markdown]
# ---
# # <font color="#CA3532">Deep Learning Fundamentals and Basic Tools (2025/2026) - Lab Assignment 3</font>
# ---
#
# Last updated on 2026-09-03
#
# Please report any bugs to emami.seyedsaman@uam.es
#
#
#
# ---

# %% [markdown]
# This third lab includes the following tasks:
#
# - The implementation of simple models using [PyTorch](https://pytorch.org/).
#
# - The implementation of recurrent neural networks using [PyTorch](https://pytorch.org/), and their application to a language modeling problem.

# %% [markdown]
# ### <font color="#CA3532">Clone the lab's github repo</font>
#
# The easiest way of having all the lab material available from *Colab* is to clone our github repository:

# %%
# !git clone https://github.com/samanemami/DLFBT-LAB.git
# Out:
# Cloning into 'DLFBT-LAB'...
# remote: Enumerating objects: 205, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 205 (delta 39), reused 40 (delta 13), pack-reused 128 (from 1)
# Receiving objects: 100% (205/205), 8.92 MiB | 13.98 MiB/s, done.
# Resolving deltas: 100% (104/104), done.

# %% [markdown]
# ### <font color="#CA3532">Instructions</font>
#
# - The assignment must be done in pairs.
#
# - All the exercises are described in this notebook. You must code your solutions in the file ``dlfbt_lab3.py`` provided as part of the material. Just complete the sections in the code marked with ``TO-DO`` comments.
#
# - The results for exercises 3 and 4 must be included at the end of this notebook.
#
# - Create a zip file containing both the ``dlfbt_lab3.py`` and this notebook and upload it to the [course Moodle page](https://posgrado.uam.es/course/view.php?id=72922) before the due date.
#
# - **Due date:** Friday, 2025-10-09, 13:00.

# %% [markdown]
# ### <font color="#CA3532">Import the libraries</font>
#
# The following code cells import the required libraries.

# %%
import pickle
import shutil
import torch
import numpy as np
from time import time
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d


import sys
sys.path.append('DLFBT-LAB')
import dlfbt

# %% [markdown]
# ### <font color="#CA3532">Introduction to PyTorch</font>
#
# [PyTorch](https://pytorch.org/) is an open source machine learning framework that can be a good alternative to [TensorFlow](https://www.tensorflow.org/). It is usually the preferred option amongst the academic comunity because it offers more flexibility and hence it is easier to build custom models. However it lacks a high level layer like [Keras](https://keras.io/), so development could be a bit harder.
#
# In this first part of the lab you will be introduced to the PyTorch framework.
#
# Follow the introductory tutorial in the [PyTorch 60-Minute Blitz](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) and then solve the exercises.

# %% [markdown]
# ### <font color="#CA3532">Automatic differentiation with PyTorch</font>

# %% [markdown]
# As you have seen in the tutorial, the flag ``requires_grad=True`` is used when creating a tensor to indicate that we will compute gradients with respect to it:

# %%
x = torch.ones(2, 2, requires_grad=True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)

# %% [markdown]
# Now, whenever we perform an operation with this tensor, the new tensor that results from this operation includes a function to compute the gradient (``grad_fn``):

# %%
y = x + 2
print(y)
# Out:
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)

# %% [markdown]
# Another example follows:

# %%
z = y * y * 3
out = z.mean()

print(z)
print(out)
# Out:
# tensor([[27., 27.],
#         [27., 27.]], grad_fn=<MulBackward0>)
# tensor(27., grad_fn=<MeanBackward0>)

# %% [markdown]
# To compute the gradients we must run the *backward pass* on the output tensor:

# %%
out.backward()

# %% [markdown]
# And then we can access the gradient using the ``grad`` field:

# %%
print(x.grad)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])

# %% [markdown]
# A simpler example, with scalar variables $x$ and $y$, follows:
#
# $$
# z = 2x^{2}y
# $$

# %%
x = torch.tensor(2., requires_grad=True)
print(x)
y = torch.tensor(3., requires_grad=True)
print(y)
z = 2*x*x*y
print(z)
# Out:
# tensor(2., requires_grad=True)
# tensor(3., requires_grad=True)
# tensor(24., grad_fn=<MulBackward0>)

# %% [markdown]
# Backward pass:

# %%
z.backward()

# %% [markdown]
# Gradients:
#
# $$
# \frac{dz}{dx} = 4xy
# $$
#
# $$
# \frac{dz}{dy} = 2x^{2}
# $$

# %%
print(x.grad)
print(y.grad)
# Out:
# tensor(24.)
# tensor(8.)

# %% [markdown]
# ### <font color="#CA3532">Exercise 1: Gradient descent to find the minimum of a function</font>
#
# In the file ``dlfbt_lab3.py``, complete the code of the function ``gradient_descent_pytorch(f, x0, learning_rate, niters)`` that finds a minimum of a function using gradient descent. The function receives the following arguments:
#
# - ``f``: the function to minimize
# - ``x0``: the initial value
# - ``learning_rate``: the learning rate
# - ``niters``: the number of iterations
#
# The function returns a Numpy array with all the values of $x$.
#
# You can run the following code to test your implementation.

# %%
from dlfbt_lab3 import gradient_descent_pytorch

# %% [markdown]
# Find the minimum of the function $f(x) = (x-4)^{2}$:

# %%
f = lambda x : (x - 4)**2
x_history = gradient_descent_pytorch(f, 0.0, 1.e-2, 500)

# Plot x versus iteration:
plt.plot(x_history)
plt.plot([0, 500], [4, 4])
plt.grid(True)
plt.legend(('Predicted', 'True'))
plt.xlabel('Iteration')
plt.ylabel('x value')
plt.show()

# %% [markdown]
# Find a local minimum of the function $f(x) = \cos x$:

# %%
f = lambda x : torch.cos(x)
x_history = gradient_descent_pytorch(f, 1.0, 1.e-2, 1000)

# Plot x versus iteration:
plt.plot(x_history)
plt.plot([0, 1000], [np.pi, np.pi])
plt.grid(True)
plt.legend(('Predicted', 'True'))
plt.xlabel('Iteration')
plt.ylabel('x value')
plt.show()

# %% [markdown]
# ### <font color="#CA3532">Exercise 2: Linear regression using pytorch</font>
#
# Re-implement the ``LinearRegressionModel`` class of lab 1 using PyTorch.
#
# Complete the code of the class ``LinearRegressionModel_pytorch`` by filling all the ``TO-DO`` blocks, so that it implements a Linear Regression model.

# %%
from dlfbt_lab3 import LinearRegressionModel_pytorch

# %% [markdown]
# Run the following tests to check your implementation.

# %% [markdown]
# Test the ``predict`` method:

# %%
dg = dlfbt.DataGeneratorLinear(a=[-5.0, 2.0, -3.0, 2.0])
dg.create_dataset(noise=0.0, n=500)

linrm = LinearRegressionModel_pytorch()
linrm.w = torch.tensor(dg.a, requires_grad=True)
linrm.b = torch.tensor(dg.b, requires_grad=True)

y = linrm.predict(dg.x).detach()

tol = 1.e-8
assert y.shape == (500, 1)
assert np.abs(y.numpy() - dg.t).max() < tol
assert linrm.get_loss(dg.x, dg.t) < tol

# %% [markdown]
# Test the ``compute_gradients`` method:

# %%
dg = dlfbt.DataGeneratorLinear(a=[-5.0, 2.0, -3.0, 2.0])
dg.create_dataset(n=50000, seed=17)

linrm = LinearRegressionModel_pytorch()
linrm.w = torch.tensor(dg.a, requires_grad=True)
linrm.b = torch.tensor(dg.b, requires_grad=True)

db, dw = linrm.compute_gradients(dg.x, dg.t)

tol = 1.e-8
assert db.shape == (1, 1)
assert np.abs(db[0][0] + 0.00704326) < tol
assert dw.shape == (4, 1)
assert np.abs(dw[0][0] + 0.05353578) < tol
assert np.abs(dw[1][0] + 0.03276935) < tol
assert np.abs(dw[2][0] + 0.00337341) < tol
assert np.abs(dw[3][0] + 0.03293776) < tol

# %% [markdown]
# Test the ``fit`` method:

# %%
dg = dlfbt.DataGeneratorLinear(a=[2.0, 2.0])
dg.create_dataset(n=500, seed=17)

linrm = LinearRegressionModel_pytorch(2)
linrm.w = torch.tensor([[-2.0], [-2.0]], dtype=torch.float64, requires_grad=True)
linrm.b = torch.tensor([[-3.0]], dtype=torch.float64, requires_grad=True)

loss = linrm.fit(dg.x, dg.t, 0.01, 100)

tol = 1.e-8
assert np.abs(loss[-1] - 2.660068435196912) < tol

# %% [markdown]
# Plot loss vs iteration:

# %%
plt.figure(figsize=(6, 6))
plt.plot(loss)
plt.xlabel('iteration')
plt.ylabel('loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### <font color="#CA3532">Neural networks in pytorch</font>

# %% [markdown]
# We will build a simple feedforward neural network to classify the digits in the [MNIST](https://keras.io/api/datasets/mnist/) dataset. The next cell loads the data:

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

print(train_images.shape)
print(train_labels.shape)
print(train_labels)

print(test_images.shape)
print(test_labels.shape)
print(test_labels)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (60000,)
# [5 0 4 ... 5 6 8]
# (10000, 28, 28)
# (10000,)
# [7 2 1 ... 4 5 6]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# Definition of a class that implements the neural network (only the forward pass):

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = self.fc2(x) # Note that we are not explicitly applying a softmax function
        return x

# %% [markdown]
# NN instantiation:

# %%
net = Net()
print(net)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# Network parameters:

# %%
params = list(net.parameters())
print(len(params))

for p in params:
  print(p.size())
# Out:
# 4
# torch.Size([64, 784])
# torch.Size([64])
# torch.Size([10, 64])
# torch.Size([10])

# %% [markdown]
# Let us apply this network to a sample image:

# %%
print(train_images[1].shape)
print("target =", train_labels[1])
plt.imshow(train_images[1], cmap='gray')
plt.show()

# Image to tensor:
input = torch.tensor(train_images[1], dtype=torch.float)

# Predict:
out = net(input)
print(out)
# Out:
# (28, 28)
# target = 0
# tensor([[-19.1540, -18.3811,  10.1557, -38.4662,  24.7372,  -6.7574,   6.5548,
#          -13.1421,  17.0890,  -3.2848]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Define the optimizer:

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# Network training:

# %%
niters = 1000
hh = []
for it in range(niters):
    # Generate random mini-batch:
    ix = np.random.permutation(60000)[:1000]
    x = torch.tensor(train_images[ix], dtype=torch.float)
    y = torch.tensor(train_labels[ix], dtype=torch.long)

    # Reset gradients:
    optimizer.zero_grad()

    # Forward pass:
    outputs = net(x)
    loss = criterion(outputs, y)

    # Backward pass:
    loss.backward()

    # Update:
    optimizer.step()

    # Print stats:
    print('[%d] loss: %.3f' % (it + 1, loss.item()))
    hh.append(loss.item())
# Out:
# [1] loss: 29.387
# [2] loss: 24.235
# [3] loss: 29.665
# [4] loss: 33.733
# [5] loss: 31.734
# [6] loss: 12.679
# [7] loss: 3.845
# [8] loss: 2.542
# [9] loss: 2.305
# [10] loss: 2.206
# [11] loss: 2.147
# [12] loss: 2.108
# [13] loss: 2.096
# [14] loss: 2.052
# [15] loss: 2.046
# [16] loss: 1.989
# [17] loss: 1.913
# [18] loss: 1.960
# [19] loss: 1.855
# [20] loss: 1.864
# [21] loss: 1.839
# [22] loss: 1.701
# [23] loss: 1.653
# [24] loss: 1.798
# [25] loss: 1.828
# [26] loss: 1.801
# [27] loss: 1.697
# [28] loss: 1.631
# [29] loss: 1.663
# [30] loss: 1.627
# [31] loss: 1.607
# [32] loss: 1.594
# [33] loss: 1.545
# [34] loss: 1.547
# [35] loss: 1.531
# [36] loss: 1.546
# [37] loss: 1.504
# [38] loss: 1.436
# [39] loss: 1.456
# [40] loss: 1.427
# [41] loss: 1.370
# [42] loss: 1.379
# [43] loss: 1.445
# [44] loss: 1.348
# [45] loss: 1.353
# [46] loss: 1.350
# [47] loss: 1.457
# [48] loss: 1.367
# [49] loss: 1.374
# [50] loss: 1.320
# [51] loss: 1.370
# [52] loss: 1.313
# [53] loss: 1.270
# [54] loss: 1.267
# [55] loss: 1.305
# [56] loss: 1.205
# [57] loss: 1.356
# [58] loss: 1.274
# [59] loss: 1.208
# [60] loss: 1.285
# [61] loss: 1.225
# [62] loss: 1.219
# [63] loss: 1.213
# [64] loss: 1.247
# [65] loss: 1.294
# [66] loss: 1.240
# [67] loss: 1.118
# [68] loss: 1.152
# [69] loss: 1.174
# [70] loss: 1.147
# [71] loss: 1.235
# [72] loss: 1.183
# [73] loss: 1.088
# [74] loss: 1.250
# [75] loss: 1.130
# [76] loss: 1.037
# [77] loss: 1.057
# [78] loss: 0.986
# [79] loss: 0.992
# [80] loss: 1.066
# [81] loss: 1.014
# [82] loss: 1.073
# [83] loss: 1.032
# [84] loss: 1.011
# [85] loss: 0.988
# [86] loss: 0.969
# [87] loss: 1.033
# [88] loss: 1.034
# [89] loss: 0.908
# [90] loss: 0.996
# [91] loss: 0.968
# [92] loss: 0.968
# [93] loss: 0.924
# [94] loss: 0.960
# [95] loss: 1.025
# [96] loss: 0.945
# [97] loss: 0.947
# [98] loss: 0.941
# [99] loss: 0.852
# [100] loss: 0.919
# [101] loss: 0.873
# [102] loss: 0.904
# [103] loss: 0.876
# [104] loss: 0.892
# [105] loss: 0.947
# [106] loss: 0.940
# [107] loss: 0.937
# [108] loss: 0.878
# [109] loss: 0.766
# [110] loss: 0.859
# [111] loss: 0.858
# [112] loss: 0.850
# [113] loss: 0.835
# [114] loss: 0.745
# [115] loss: 0.772
# [116] loss: 0.824
# [117] loss: 0.789
# [118] loss: 0.771
# [119] loss: 0.818
# [120] loss: 0.816
# [121] loss: 0.736
# [122] loss: 0.820
# [123] loss: 0.842
# [124] loss: 0.860
# [125] loss: 0.802
# [126] loss: 0.737
# [127] loss: 0.767
# [128] loss: 0.770
# [129] loss: 0.727
# [130] loss: 0.788
# [131] loss: 0.718
# [132] loss: 0.635
# [133] loss: 0.715
# [134] loss: 0.743
# [135] loss: 0.769
# [136] loss: 0.674
# [137] loss: 0.667
# [138] loss: 0.740
# [139] loss: 0.632
# [140] loss: 0.764
# [141] loss: 0.622
# [142] loss: 0.659
# [143] loss: 0.583
# [144] loss: 0.760
# [145] loss: 0.705
# [146] loss: 0.664
# [147] loss: 0.717
# [148] loss: 0.650
# [149] loss: 0.586
# [150] loss: 0.654
# [151] loss: 0.648
# [152] loss: 0.667
# [153] loss: 0.613
# [154] loss: 0.580
# [155] loss: 0.711
# [156] loss: 0.686
# [157] loss: 0.644
# [158] loss: 0.618
# [159] loss: 0.650
# [160] loss: 0.581
# [161] loss: 0.712
# [162] loss: 0.591
# [163] loss: 0.714
# [164] loss: 0.658
# [165] loss: 0.549
# [166] loss: 0.620
# [167] loss: 0.572
# [168] loss: 0.589
# [169] loss: 0.620
# [170] loss: 0.594
# [171] loss: 0.625
# [172] loss: 0.600
# [173] loss: 0.587
# [174] loss: 0.524
# [175] loss: 0.577
# [176] loss: 0.538
# [177] loss: 0.546
# [178] loss: 0.627
# [179] loss: 0.577
# [180] loss: 0.585
# [181] loss: 0.568
# [182] loss: 0.587
# [183] loss: 0.635
# [184] loss: 0.555
# [185] loss: 0.580
# [186] loss: 0.571
# [187] loss: 0.539
# [188] loss: 0.555
# [189] loss: 0.562
# [190] loss: 0.538
# [191] loss: 0.545
# [192] loss: 0.532
# [193] loss: 0.547
# [194] loss: 0.570
# [195] loss: 0.541
# [196] loss: 0.555
# [197] loss: 0.553
# [198] loss: 0.491
# [199] loss: 0.499
# [200] loss: 0.619
# [201] loss: 0.551
# [202] loss: 0.543
# [203] loss: 0.503
# [204] loss: 0.568
# [205] loss: 0.524
# [206] loss: 0.481
# [207] loss: 0.482
# [208] loss: 0.570
# [209] loss: 0.485
# [210] loss: 0.547
# [211] loss: 0.524
# [212] loss: 0.477
# [213] loss: 0.457
# [214] loss: 0.500
# [215] loss: 0.446
# [216] loss: 0.501
# [217] loss: 0.523
# [218] loss: 0.475
# [219] loss: 0.486
# [220] loss: 0.514
# [221] loss: 0.508
# [222] loss: 0.496
# [223] loss: 0.537
# [224] loss: 0.481
# [225] loss: 0.510
# [226] loss: 0.465
# [227] loss: 0.488
# [228] loss: 0.482
# [229] loss: 0.477
# [230] loss: 0.466
# [231] loss: 0.416
# [232] loss: 0.485
# [233] loss: 0.530
# [234] loss: 0.500
# [235] loss: 0.474
# [236] loss: 0.418
# [237] loss: 0.470
# [238] loss: 0.473
# [239] loss: 0.486
# [240] loss: 0.428
# [241] loss: 0.491
# [242] loss: 0.421
# [243] loss: 0.527
# [244] loss: 0.434
# [245] loss: 0.471
# [246] loss: 0.523
# [247] loss: 0.509
# [248] loss: 0.460
# [249] loss: 0.542
# [250] loss: 0.449
# [251] loss: 0.509
# [252] loss: 0.493
# [253] loss: 0.495
# [254] loss: 0.451
# [255] loss: 0.468
# [256] loss: 0.500
# [257] loss: 0.497
# [258] loss: 0.443
# [259] loss: 0.421
# [260] loss: 0.472
# [261] loss: 0.437
# [262] loss: 0.431
# [263] loss: 0.453
# [264] loss: 0.399
# [265] loss: 0.493
# [266] loss: 0.492
# [267] loss: 0.456
# [268] loss: 0.426
# [269] loss: 0.479
# [270] loss: 0.458
# [271] loss: 0.481
# [272] loss: 0.428
# [273] loss: 0.419
# [274] loss: 0.483
# [275] loss: 0.466
# [276] loss: 0.466
# [277] loss: 0.417
# [278] loss: 0.362
# [279] loss: 0.428
# [280] loss: 0.409
# [281] loss: 0.451
# [282] loss: 0.469
# [283] loss: 0.458
# [284] loss: 0.387
# [285] loss: 0.404
# [286] loss: 0.472
# [287] loss: 0.467
# [288] loss: 0.417
# [289] loss: 0.412
# [290] loss: 0.404
# [291] loss: 0.431
# [292] loss: 0.453
# [293] loss: 0.423
# [294] loss: 0.439
# [295] loss: 0.390
# [296] loss: 0.396
# [297] loss: 0.414
# [298] loss: 0.424
# [299] loss: 0.487
# [300] loss: 0.350
# [301] loss: 0.415
# [302] loss: 0.419
# [303] loss: 0.419
# [304] loss: 0.428
# [305] loss: 0.416
# [306] loss: 0.491
# [307] loss: 0.406
# [308] loss: 0.418
# [309] loss: 0.368
# [310] loss: 0.427
# [311] loss: 0.410
# [312] loss: 0.421
# [313] loss: 0.388
# [314] loss: 0.384
# [315] loss: 0.423
# [316] loss: 0.384
# [317] loss: 0.414
# [318] loss: 0.370
# [319] loss: 0.359
# [320] loss: 0.396
# [321] loss: 0.404
# [322] loss: 0.366
# [323] loss: 0.403
# [324] loss: 0.373
# [325] loss: 0.399
# [326] loss: 0.369
# [327] loss: 0.449
# [328] loss: 0.426
# [329] loss: 0.382
# [330] loss: 0.387
# [331] loss: 0.410
# [332] loss: 0.400
# [333] loss: 0.422
# [334] loss: 0.362
# [335] loss: 0.349
# [336] loss: 0.404
# [337] loss: 0.390
# [338] loss: 0.406
# [339] loss: 0.364
# [340] loss: 0.399
# [341] loss: 0.438
# [342] loss: 0.335
# [343] loss: 0.428
# [344] loss: 0.405
# [345] loss: 0.336
# [346] loss: 0.348
# [347] loss: 0.400
# [348] loss: 0.367
# [349] loss: 0.388
# [350] loss: 0.391
# [351] loss: 0.394
# [352] loss: 0.334
# [353] loss: 0.362
# [354] loss: 0.378
# [355] loss: 0.440
# [356] loss: 0.356
# [357] loss: 0.354
# [358] loss: 0.394
# [359] loss: 0.369
# [360] loss: 0.381
# [361] loss: 0.361
# [362] loss: 0.427
# [363] loss: 0.422
# [364] loss: 0.431
# [365] loss: 0.396
# [366] loss: 0.340
# [367] loss: 0.368
# [368] loss: 0.377
# [369] loss: 0.440
# [370] loss: 0.415
# [371] loss: 0.313
# [372] loss: 0.442
# [373] loss: 0.343
# [374] loss: 0.367
# [375] loss: 0.425
# [376] loss: 0.362
# [377] loss: 0.365
# [378] loss: 0.377
# [379] loss: 0.384
# [380] loss: 0.386
# [381] loss: 0.333
# [382] loss: 0.387
# [383] loss: 0.333
# [384] loss: 0.453
# [385] loss: 0.406
# [386] loss: 0.343
# [387] loss: 0.427
# [388] loss: 0.341
# [389] loss: 0.314
# [390] loss: 0.384
# [391] loss: 0.363
# [392] loss: 0.412
# [393] loss: 0.370
# [394] loss: 0.363
# [395] loss: 0.319
# [396] loss: 0.415
# [397] loss: 0.313
# [398] loss: 0.378
# [399] loss: 0.359
# [400] loss: 0.300
# [401] loss: 0.385
# [402] loss: 0.363
# [403] loss: 0.399
# [404] loss: 0.334
# [405] loss: 0.304
# [406] loss: 0.365
# [407] loss: 0.358
# [408] loss: 0.353
# [409] loss: 0.338
# [410] loss: 0.378
# [411] loss: 0.344
# [412] loss: 0.341
# [413] loss: 0.398
# [414] loss: 0.382
# [415] loss: 0.405
# [416] loss: 0.331
# [417] loss: 0.393
# [418] loss: 0.385
# [419] loss: 0.371
# [420] loss: 0.316
# [421] loss: 0.317
# [422] loss: 0.364
# [423] loss: 0.464
# [424] loss: 0.356
# [425] loss: 0.372
# [426] loss: 0.354
# [427] loss: 0.345
# [428] loss: 0.405
# [429] loss: 0.285
# [430] loss: 0.341
# [431] loss: 0.351
# [432] loss: 0.290
# [433] loss: 0.330
# [434] loss: 0.302
# [435] loss: 0.355
# [436] loss: 0.339
# [437] loss: 0.316
# [438] loss: 0.316
# [439] loss: 0.381
# [440] loss: 0.326
# [441] loss: 0.367
# [442] loss: 0.353
# [443] loss: 0.400
# [444] loss: 0.344
# [445] loss: 0.326
# [446] loss: 0.371
# [447] loss: 0.297
# [448] loss: 0.384
# [449] loss: 0.258
# [450] loss: 0.254
# [451] loss: 0.368
# [452] loss: 0.369
# [453] loss: 0.296
# [454] loss: 0.339
# [455] loss: 0.320
# [456] loss: 0.338
# [457] loss: 0.378
# [458] loss: 0.384
# [459] loss: 0.356
# [460] loss: 0.313
# [461] loss: 0.326
# [462] loss: 0.336
# [463] loss: 0.329
# [464] loss: 0.291
# [465] loss: 0.357
# [466] loss: 0.332
# [467] loss: 0.364
# [468] loss: 0.297
# [469] loss: 0.310
# [470] loss: 0.283
# [471] loss: 0.365
# [472] loss: 0.322
# [473] loss: 0.332
# [474] loss: 0.385
# [475] loss: 0.337
# [476] loss: 0.392
# [477] loss: 0.343
# [478] loss: 0.322
# [479] loss: 0.373
# [480] loss: 0.385
# [481] loss: 0.337
# [482] loss: 0.345
# [483] loss: 0.330
# [484] loss: 0.325
# [485] loss: 0.300
# [486] loss: 0.325
# [487] loss: 0.355
# [488] loss: 0.280
# [489] loss: 0.324
# [490] loss: 0.350
# [491] loss: 0.328
# [492] loss: 0.330
# [493] loss: 0.344
# [494] loss: 0.363
# [495] loss: 0.318
# [496] loss: 0.338
# [497] loss: 0.319
# [498] loss: 0.345
# [499] loss: 0.366
# [500] loss: 0.354
# [501] loss: 0.316
# [502] loss: 0.365
# [503] loss: 0.289
# [504] loss: 0.377
# [505] loss: 0.303
# [506] loss: 0.293
# [507] loss: 0.318
# [508] loss: 0.335
# [509] loss: 0.362
# [510] loss: 0.326
# [511] loss: 0.349
# [512] loss: 0.304
# [513] loss: 0.296
# [514] loss: 0.302
# [515] loss: 0.313
# [516] loss: 0.343
# [517] loss: 0.294
# [518] loss: 0.331
# [519] loss: 0.271
# [520] loss: 0.309
# [521] loss: 0.291
# [522] loss: 0.335
# [523] loss: 0.316
# [524] loss: 0.366
# [525] loss: 0.278
# [526] loss: 0.307
# [527] loss: 0.298
# [528] loss: 0.321
# [529] loss: 0.334
# [530] loss: 0.316
# [531] loss: 0.321
# [532] loss: 0.290
# [533] loss: 0.349
# [534] loss: 0.318
# [535] loss: 0.323
# [536] loss: 0.246
# [537] loss: 0.321
# [538] loss: 0.311
# [539] loss: 0.322
# [540] loss: 0.354
# [541] loss: 0.338
# [542] loss: 0.305
# [543] loss: 0.281
# [544] loss: 0.297
# [545] loss: 0.308
# [546] loss: 0.299
# [547] loss: 0.287
# [548] loss: 0.314
# [549] loss: 0.337
# [550] loss: 0.333
# [551] loss: 0.309
# [552] loss: 0.315
# [553] loss: 0.334
# [554] loss: 0.279
# [555] loss: 0.332
# [556] loss: 0.310
# [557] loss: 0.401
# [558] loss: 0.295
# [559] loss: 0.337
# [560] loss: 0.300
# [561] loss: 0.346
# [562] loss: 0.313
# [563] loss: 0.288
# [564] loss: 0.313
# [565] loss: 0.337
# [566] loss: 0.325
# [567] loss: 0.349
# [568] loss: 0.293
# [569] loss: 0.339
# [570] loss: 0.379
# [571] loss: 0.294
# [572] loss: 0.342
# [573] loss: 0.283
# [574] loss: 0.336
# [575] loss: 0.382
# [576] loss: 0.356
# [577] loss: 0.324
# [578] loss: 0.410
# [579] loss: 0.306
# [580] loss: 0.319
# [581] loss: 0.339
# [582] loss: 0.383
# [583] loss: 0.341
# [584] loss: 0.336
# [585] loss: 0.333
# [586] loss: 0.350
# [587] loss: 0.290
# [588] loss: 0.347
# [589] loss: 0.283
# [590] loss: 0.303
# [591] loss: 0.318
# [592] loss: 0.305
# [593] loss: 0.235
# [594] loss: 0.347
# [595] loss: 0.365
# [596] loss: 0.337
# [597] loss: 0.330
# [598] loss: 0.346
# [599] loss: 0.305
# [600] loss: 0.351
# [601] loss: 0.360
# [602] loss: 0.321
# [603] loss: 0.349
# [604] loss: 0.331
# [605] loss: 0.267
# [606] loss: 0.323
# [607] loss: 0.267
# [608] loss: 0.350
# [609] loss: 0.389
# [610] loss: 0.284
# [611] loss: 0.249
# [612] loss: 0.298
# [613] loss: 0.319
# [614] loss: 0.337
# [615] loss: 0.273
# [616] loss: 0.331
# [617] loss: 0.299
# [618] loss: 0.296
# [619] loss: 0.311
# [620] loss: 0.269
# [621] loss: 0.340
# [622] loss: 0.345
# [623] loss: 0.315
# [624] loss: 0.299
# [625] loss: 0.304
# [626] loss: 0.306
# [627] loss: 0.320
# [628] loss: 0.290
# [629] loss: 0.304
# [630] loss: 0.314
# [631] loss: 0.272
# [632] loss: 0.364
# [633] loss: 0.326
# [634] loss: 0.290
# [635] loss: 0.303
# [636] loss: 0.371
# [637] loss: 0.304
# [638] loss: 0.321
# [639] loss: 0.319
# [640] loss: 0.288
# [641] loss: 0.339
# [642] loss: 0.274
# [643] loss: 0.292
# [644] loss: 0.330
# [645] loss: 0.314
# [646] loss: 0.277
# [647] loss: 0.303
# [648] loss: 0.287
# [649] loss: 0.265
# [650] loss: 0.287
# [651] loss: 0.300
# [652] loss: 0.257
# [653] loss: 0.251
# [654] loss: 0.234
# [655] loss: 0.272
# [656] loss: 0.272
# [657] loss: 0.336
# [658] loss: 0.292
# [659] loss: 0.300
# [660] loss: 0.345
# [661] loss: 0.301
# [662] loss: 0.298
# [663] loss: 0.270
# [664] loss: 0.353
# [665] loss: 0.275
# [666] loss: 0.306
# [667] loss: 0.285
# [668] loss: 0.275
# [669] loss: 0.391
# [670] loss: 0.309
# [671] loss: 0.350
# [672] loss: 0.257
# [673] loss: 0.268
# [674] loss: 0.268
# [675] loss: 0.293
# [676] loss: 0.251
# [677] loss: 0.326
# [678] loss: 0.310
# [679] loss: 0.329
# [680] loss: 0.278
# [681] loss: 0.351
# [682] loss: 0.268
# [683] loss: 0.220
# [684] loss: 0.236
# [685] loss: 0.318
# [686] loss: 0.318
# [687] loss: 0.341
# [688] loss: 0.333
# [689] loss: 0.240
# [690] loss: 0.275
# [691] loss: 0.269
# [692] loss: 0.302
# [693] loss: 0.297
# [694] loss: 0.268
# [695] loss: 0.322
# [696] loss: 0.280
# [697] loss: 0.306
# [698] loss: 0.259
# [699] loss: 0.288
# [700] loss: 0.301
# [701] loss: 0.316
# [702] loss: 0.326
# [703] loss: 0.276
# [704] loss: 0.339
# [705] loss: 0.273
# [706] loss: 0.245
# [707] loss: 0.308
# [708] loss: 0.285
# [709] loss: 0.259
# [710] loss: 0.279
# [711] loss: 0.280
# [712] loss: 0.278
# [713] loss: 0.298
# [714] loss: 0.301
# [715] loss: 0.252
# [716] loss: 0.346
# [717] loss: 0.273
# [718] loss: 0.303
# [719] loss: 0.322
# [720] loss: 0.318
# [721] loss: 0.345
# [722] loss: 0.269
# [723] loss: 0.295
# [724] loss: 0.302
# [725] loss: 0.379
# [726] loss: 0.321
# [727] loss: 0.310
# [728] loss: 0.276
# [729] loss: 0.302
# [730] loss: 0.284
# [731] loss: 0.315
# [732] loss: 0.329
# [733] loss: 0.343
# [734] loss: 0.300
# [735] loss: 0.275
# [736] loss: 0.264
# [737] loss: 0.322
# [738] loss: 0.322
# [739] loss: 0.318
# [740] loss: 0.249
# [741] loss: 0.307
# [742] loss: 0.284
# [743] loss: 0.317
# [744] loss: 0.261
# [745] loss: 0.270
# [746] loss: 0.283
# [747] loss: 0.276
# [748] loss: 0.324
# [749] loss: 0.339
# [750] loss: 0.333
# [751] loss: 0.283
# [752] loss: 0.287
# [753] loss: 0.287
# [754] loss: 0.280
# [755] loss: 0.256
# [756] loss: 0.273
# [757] loss: 0.231
# [758] loss: 0.299
# [759] loss: 0.280
# [760] loss: 0.338
# [761] loss: 0.262
# [762] loss: 0.291
# [763] loss: 0.233
# [764] loss: 0.263
# [765] loss: 0.330
# [766] loss: 0.339
# [767] loss: 0.280
# [768] loss: 0.276
# [769] loss: 0.272
# [770] loss: 0.267
# [771] loss: 0.252
# [772] loss: 0.299
# [773] loss: 0.249
# [774] loss: 0.298
# [775] loss: 0.240
# [776] loss: 0.259
# [777] loss: 0.298
# [778] loss: 0.295
# [779] loss: 0.290
# [780] loss: 0.280
# [781] loss: 0.343
# [782] loss: 0.306
# [783] loss: 0.310
# [784] loss: 0.261
# [785] loss: 0.279
# [786] loss: 0.315
# [787] loss: 0.296
# [788] loss: 0.275
# [789] loss: 0.275
# [790] loss: 0.283
# [791] loss: 0.309
# [792] loss: 0.286
# [793] loss: 0.269
# [794] loss: 0.293
# [795] loss: 0.289
# [796] loss: 0.264
# [797] loss: 0.289
# [798] loss: 0.236
# [799] loss: 0.275
# [800] loss: 0.279
# [801] loss: 0.353
# [802] loss: 0.308
# [803] loss: 0.288
# [804] loss: 0.333
# [805] loss: 0.280
# [806] loss: 0.276
# [807] loss: 0.283
# [808] loss: 0.288
# [809] loss: 0.255
# [810] loss: 0.243
# [811] loss: 0.355
# [812] loss: 0.314
# [813] loss: 0.271
# [814] loss: 0.235
# [815] loss: 0.276
# [816] loss: 0.265
# [817] loss: 0.269
# [818] loss: 0.318
# [819] loss: 0.287
# [820] loss: 0.261
# [821] loss: 0.280
# [822] loss: 0.299
# [823] loss: 0.279
# [824] loss: 0.274
# [825] loss: 0.260
# [826] loss: 0.299
# [827] loss: 0.273
# [828] loss: 0.208
# [829] loss: 0.308
# [830] loss: 0.289
# [831] loss: 0.246
# [832] loss: 0.263
# [833] loss: 0.256
# [834] loss: 0.306
# [835] loss: 0.280
# [836] loss: 0.260
# [837] loss: 0.283
# [838] loss: 0.263
# [839] loss: 0.241
# [840] loss: 0.295
# [841] loss: 0.282
# [842] loss: 0.318
# [843] loss: 0.289
# [844] loss: 0.289
# [845] loss: 0.306
# [846] loss: 0.253
# [847] loss: 0.327
# [848] loss: 0.292
# [849] loss: 0.265
# [850] loss: 0.316
# [851] loss: 0.272
# [852] loss: 0.299
# [853] loss: 0.269
# [854] loss: 0.261
# [855] loss: 0.266
# [856] loss: 0.312
# [857] loss: 0.265
# [858] loss: 0.262
# [859] loss: 0.345
# [860] loss: 0.329
# [861] loss: 0.245
# [862] loss: 0.295
# [863] loss: 0.268
# [864] loss: 0.267
# [865] loss: 0.250
# [866] loss: 0.275
# [867] loss: 0.205
# [868] loss: 0.285
# [869] loss: 0.284
# [870] loss: 0.278
# [871] loss: 0.267
# [872] loss: 0.237
# [873] loss: 0.256
# [874] loss: 0.265
# [875] loss: 0.270
# [876] loss: 0.271
# [877] loss: 0.260
# [878] loss: 0.268
# [879] loss: 0.279
# [880] loss: 0.321
# [881] loss: 0.268
# [882] loss: 0.314
# [883] loss: 0.275
# [884] loss: 0.263
# [885] loss: 0.251
# [886] loss: 0.298
# [887] loss: 0.263
# [888] loss: 0.285
# [889] loss: 0.317
# [890] loss: 0.249
# [891] loss: 0.281
# [892] loss: 0.254
# [893] loss: 0.306
# [894] loss: 0.267
# [895] loss: 0.246
# [896] loss: 0.258
# [897] loss: 0.263
# [898] loss: 0.260
# [899] loss: 0.284
# [900] loss: 0.273
# [901] loss: 0.242
# [902] loss: 0.268
# [903] loss: 0.234
# [904] loss: 0.225
# [905] loss: 0.239
# [906] loss: 0.238
# [907] loss: 0.319
# [908] loss: 0.263
# [909] loss: 0.271
# [910] loss: 0.280
# [911] loss: 0.262
# [912] loss: 0.238
# [913] loss: 0.277
# [914] loss: 0.279
# [915] loss: 0.254
# [916] loss: 0.258
# [917] loss: 0.269
# [918] loss: 0.286
# [919] loss: 0.290
# [920] loss: 0.305
# [921] loss: 0.335
# [922] loss: 0.273
# [923] loss: 0.250
# [924] loss: 0.265
# [925] loss: 0.272
# [926] loss: 0.259
# [927] loss: 0.205
# [928] loss: 0.263
# [929] loss: 0.281
# [930] loss: 0.261
# [931] loss: 0.287
# [932] loss: 0.286
# [933] loss: 0.246
# [934] loss: 0.211
# [935] loss: 0.289
# [936] loss: 0.268
# [937] loss: 0.262
# [938] loss: 0.231
# [939] loss: 0.219
# [940] loss: 0.253
# [941] loss: 0.248
# [942] loss: 0.245
# [943] loss: 0.291
# [944] loss: 0.273
# [945] loss: 0.286
# [946] loss: 0.269
# [947] loss: 0.264
# [948] loss: 0.248
# [949] loss: 0.263
# [950] loss: 0.243
# [951] loss: 0.223
# [952] loss: 0.282
# [953] loss: 0.278
# [954] loss: 0.232
# [955] loss: 0.295
# [956] loss: 0.266
# [957] loss: 0.258
# [958] loss: 0.305
# [959] loss: 0.234
# [960] loss: 0.262
# [961] loss: 0.288
# [962] loss: 0.293
# [963] loss: 0.308
# [964] loss: 0.279
# [965] loss: 0.229
# [966] loss: 0.325
# [967] loss: 0.233
# [968] loss: 0.249
# [969] loss: 0.235
# [970] loss: 0.295
# [971] loss: 0.319
# [972] loss: 0.270
# [973] loss: 0.312
# [974] loss: 0.273
# [975] loss: 0.220
# [976] loss: 0.246
# [977] loss: 0.249
# [978] loss: 0.249
# [979] loss: 0.261
# [980] loss: 0.255
# [981] loss: 0.304
# [982] loss: 0.300
# [983] loss: 0.338
# [984] loss: 0.243
# [985] loss: 0.259
# [986] loss: 0.282
# [987] loss: 0.261
# [988] loss: 0.273
# [989] loss: 0.262
# [990] loss: 0.269
# [991] loss: 0.246
# [992] loss: 0.267
# [993] loss: 0.234
# [994] loss: 0.276
# [995] loss: 0.274
# [996] loss: 0.280
# [997] loss: 0.283
# [998] loss: 0.268
# [999] loss: 0.267
# [1000] loss: 0.242

# %% [markdown]
# Plot:

# %%
plt.plot(hh)
plt.grid(True)
plt.show()

# %% [markdown]
# Let us classify the same image after training:

# %%
print(train_images[1].shape)
print("target =", train_labels[1])
plt.imshow(train_images[1], cmap='gray')
plt.show()

# Image to tensor:
input = torch.tensor(train_images[1], dtype=torch.float)

# Predict:
out = net(input)
print(out)
# Out:
# (28, 28)
# target = 0
# tensor([[ 10.0027, -11.5732,  -3.0918, -12.2168,  -3.7182,  -1.1258,  -4.2408,
#           -3.2823,  -7.1101,  -2.5736]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Now the highest output is assigned to the correct target.

# %% [markdown]
# Accuracy on training data:

# %%
input = torch.tensor(train_images, dtype=torch.float)
out = net(input)
_, predicted = torch.max(out, 1)
(predicted.numpy() == train_labels).sum() / 60000
# Out:
# np.float64(0.9138333333333334)

# %% [markdown]
# Accuracy on test data:

# %%
input = torch.tensor(test_images, dtype=torch.float)
out = net(input)
_, predicted = torch.max(out, 1)
(predicted.numpy() == test_labels).sum() / 10000
# Out:
# np.float64(0.9065)

# %% [markdown]
# PyTorch offers some utilities to process batches of data:

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# Let us build ``DataLoader``s for training and test data:

# %%
tensor_x = torch.tensor(train_images, dtype=torch.float)
tensor_y = torch.tensor(train_labels, dtype=torch.long)
train_dataset = TensorDataset(tensor_x, tensor_y)
train_dataloader = DataLoader(train_dataset, batch_size=1000, shuffle=True)

tensor_x = torch.tensor(test_images, dtype=torch.float)
tensor_y = torch.tensor(test_labels, dtype=torch.long)
test_dataset = TensorDataset(tensor_x,tensor_y)
test_dataloader = DataLoader(test_dataset, batch_size=1000, shuffle=True)

# %% [markdown]
# New network:

# %%
net = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# Reimplement the training loop using epochs and batches:

# %%
nepochs = 10
hh = []
for it in range(nepochs):
  rloss = 0.0
  for x, t in train_dataloader:
    # Reset gradients to 0:
    optimizer.zero_grad()

    # Forward pass:
    outputs = net(x)
    loss = criterion(outputs, t)

    # Backward pass:
    loss.backward()

    # Actualización de los pesos:
    optimizer.step()

    # Acumulo loss:
    rloss += loss.item()

  # Imprimir loss de la época:
  print('[%d] loss: %.3f' % (it + 1, rloss))
  hh.append(rloss)
# Out:
# [1] loss: 165.817
# [2] loss: 33.012
# [3] loss: 23.012
# [4] loss: 18.976
# [5] loss: 16.832
# [6] loss: 15.466
# [7] loss: 14.503
# [8] loss: 13.813
# [9] loss: 13.171
# [10] loss: 12.708

# %% [markdown]
# Accuracy on training and test data:

# %%
input = torch.tensor(train_images, dtype=torch.float)
out = net(input)
_, predicted = torch.max(out, 1)
(predicted.numpy() == train_labels).sum() / 60000
# Out:
# np.float64(0.9408333333333333)

# %%
input = torch.tensor(test_images, dtype=torch.float)
out = net(input)
_, predicted = torch.max(out, 1)
(predicted.numpy() == test_labels).sum() / 10000
# Out:
# np.float64(0.9379)

# %% [markdown]
# ### <font color="#CA3532">Exercise 3: Recurrent Neural Networks with PyTorch</font>
#
# Complete the code of the class ``RNN`` in the file ``dlfbt_lab3.py``. Then run the following code to test your implementation. It is not allowed to use PyTorch classes other than ``torch.nn.Linear``.

# %% [markdown]
# ### Apply your network to detect the presence of a given pattern in a bit sequence
#
# As a first test, you will apply your network to the problem that we defined in example 2 of https://luisferuam.github.io/DLFBT/recurrent_neural_networks/recurrent_neural_networks.html

# %% [markdown]
# Dataset creation:

# %%
def create_data_set(n, seq_len, pattern):
  x = np.random.randint(0, 2, (n, seq_len))

  x_as_string = [''.join([chr(c+48) for c in a]) for a in x]
  t = np.array([pattern in s for s in x_as_string])*1

  return x, x_as_string, t

# %%
n = 50000
seq_len = 25
pattern = '11011'

x, x_as_string, t = create_data_set(n, seq_len, pattern)
xval, xval_as_string, tval = create_data_set(n, seq_len, pattern)

for s, c in zip(x_as_string[:20], t[:20]):
  print(s, c)

print('Class mean (training):', t.mean())
print('Class mean (validation):', tval.mean())
# Out:
# 0101010010010000100100010 0
# 1000111100100100000000000 0
# 1001110100101111000110001 0
# 1100000000111001101100110 1
# 1110001011100000001010101 0
# 0011011100101111011110111 1
# 0010110001010100101100011 0
# 0000001111000010111011011 1
# 1111000001011100001110010 0
# 0010111101001011110101111 0
# 1101000001010001010100110 0
# 0111011100010011100101000 1
# 1101001111011001000001001 1
# 1101100101010110111001001 1
# 0001110110001101001110011 1
# 1010011111100000011011101 1
# 0001010100110111000111111 1
# 0100111111111011100110010 1
# 1110110111111100010111101 1
# 0111000001100011111110000 0
# Class mean (training): 0.46782
# Class mean (validation): 0.46948

# %%
print(x.shape)
print(t.shape)
# Out:
# (50000, 25)
# (50000,)

# %% [markdown]
# Data loader for generating batches:

# %%
batch_size = 32

tensor_x = torch.tensor(x, dtype=torch.float)
tensor_t = torch.tensor(t, dtype=torch.long)
train_dataset = TensorDataset(tensor_x[:, :, None], tensor_t)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# Test for the RNN implementation:

# %%
from dlfbt_lab3 import RNN

# %%
class Network(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Network, self).__init__()

        self.rnn = RNN(input_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden):
        _, x = self.rnn(input, hidden)
        output = self.h2o(x)

        return output

# %%
hidden_size = 10
net = Network(1, hidden_size, 2)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# %%
nepochs = 10
hh = []
acc = []
for it in range(nepochs):
  rloss = 0.0
  racc = 0.0
  for xbatch, tbatch in train_dataloader:
    # Reset gradients to 0:
    optimizer.zero_grad()

    # Forward pass:
    outputs = net(xbatch, torch.zeros(xbatch.shape[0], hidden_size))
    loss = criterion(outputs, tbatch)

    # Backward pass:
    loss.backward()

    # Weights update:
    optimizer.step()

    # Loss:
    rloss += loss.item()

    # Accuracy:
    preds = np.argmax(outputs.detach(), axis=1)
    racc += (preds == tbatch).numpy().mean()

  # Prints:
  rloss /= len(train_dataloader)
  racc /= len(train_dataloader)
  print('[%d] loss = %.3f, acc = %.3f' % (it + 1, rloss, racc))
  hh.append(rloss)
  acc.append(racc)
# Out:
# [1] loss = 0.636, acc = 0.627
# [2] loss = 0.571, acc = 0.705
# [3] loss = 0.357, acc = 0.851
# [4] loss = 0.132, acc = 0.962
# [5] loss = 0.045, acc = 0.992
# [6] loss = 0.034, acc = 0.995
# [7] loss = 0.014, acc = 0.999
# [8] loss = 0.008, acc = 1.000
# [9] loss = 0.004, acc = 1.000
# [10] loss = 0.037, acc = 0.996

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(hh)
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(acc)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Compare with the PyTorch implementation
#
# Re-implement the ``Network`` class using ``torch.nn.RNN`` instead of ``dlfbt_lab3.RNN`` and compare the results, both in terms of accuracy and execution time. Include your results, plots and conclusiones in the following cells. It can be a good idea to run the experiments several times to obtain averages.

# %%
### To do: include here your comparison between dlfbt_lab3.RNN and torch.nn.RNN.

# %% [markdown]
# ### <font color="#CA3532">Exercise 4: Implementation of an LSTM</font>
#
# Complete the code of the class ``LSTM`` in the file ``dlfbt_lab3.py``. Then run the following code to test your implementation. It is not allowed to use PyTorch classes other than ``torch.nn.Linear``.

# %%
from dlfbt_lab3 import LSTM

# %% [markdown]
# ### Apply your network to the parity problem
#
# As a first test, you will apply your network to the parity problem that we defined in example 1 of https://luisferuam.github.io/DLFBT/recurrent_neural_networks/recurrent_neural_networks.html

# %% [markdown]
# This function generates the random input and output sequences:

# %%
def generate_sequences(n, p0, p1):
  """
  n is the number of elements in the sequence
  p0 and p1 must be probabilities, with p0 + p1 <= 1
  the probability for the $ symbol is assumed to be p$ = 1 - p0 - p1
  """
  r = np.random.rand(n)
  x_sym = np.full(n, '$')
  x = np.full(n, 2)
  x_sym[r < p0 + p1] = '1'
  x[r < p0 + p1] = 1
  x_sym[r < p0] = '0'
  x[r < p0] = 0
  x_sym[0] = '$'
  x[0] = 2
  t = np.zeros(n, dtype=int)
  k = 0
  for i in range(n):
    if x[i] == 2:
      t[i] = 0
      k = 0
    else:
      k += x[i]
      t[i] = k%2

  x_string = ''.join(x_sym)
  t_string = ''.join([chr(c+48) for c in t])

  x_one_hot = 1*(np.arange(3)[:, None] == x[None, :])

  return x, t, x_one_hot, x_string, t_string

# %% [markdown]
# Here we create sequences of length 5000:

# %%
num_pats = 5000
x, t, x_one_hot, x_string, t_string = generate_sequences(num_pats, 0.45, 0.45)

# %% [markdown]
# Next we define the network. Note that the input size is 3 (number of input symbols: ``0``, ``1`` or ``$``) and the output size is 2 (the parity can be either 0 or 1). The number of hidden units is arbitrary.

# %%
class ParityProblemNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ParityProblemNetwork, self).__init__()

        self.lstm = LSTM(input_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)

    def forward(self, input, h0, c0):
        x, h, c = self.lstm(input, h0, c0)
        output = self.h2o(x)

        return output, h, c

# %%
hidden_size = 10
net = ParityProblemNetwork(3, hidden_size, 2)

# %% [markdown]
# Loss function and optimizer:

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters())

# %% [markdown]
# Network training:

# %%
nepochs = 30
seq_len = 25
hh = []
acc = []
for it in range(nepochs):
  rloss = 0.0
  racc = 0.0
  ix = 0
  h = torch.zeros(1, hidden_size)
  c = torch.zeros(1, hidden_size)
  niters = x_one_hot.transpose().shape[0] // seq_len
  while ix + seq_len <= x_one_hot.transpose().shape[0]:
    xbatch = torch.tensor(x_one_hot.transpose()[None, ix:ix+seq_len, :], dtype=torch.float)
    tbatch = torch.tensor(t[None, ix:ix+seq_len], dtype=torch.long)
    ix += seq_len

    # Reset gradients to 0:
    optimizer.zero_grad()

    # Forward pass:
    output, h, c = net(xbatch, h, c)
    h = h.detach()
    c = c.detach()
    loss = criterion(torch.transpose(output, 1, 2), tbatch)

    # Backward pass:
    loss.backward()

    # Weights update:
    optimizer.step()

    # Loss:
    rloss += loss.item()

    # Accuracy:
    preds = np.argmax(output.detach(), axis=2)
    racc += (preds == tbatch).numpy().mean()

  # Prints:
  rloss /= niters
  racc /= niters
  print('[%d] loss = %.3f, acc = %.3f' % (it + 1, rloss, racc))
  hh.append(rloss)
  acc.append(racc)
# Out:
# [1] loss = 0.685, acc = 0.551
# [2] loss = 0.660, acc = 0.570
# [3] loss = 0.632, acc = 0.602
# [4] loss = 0.607, acc = 0.603
# [5] loss = 0.569, acc = 0.641
# [6] loss = 0.506, acc = 0.720
# [7] loss = 0.346, acc = 0.880
# [8] loss = 0.083, acc = 0.998
# [9] loss = 0.041, acc = 0.999
# [10] loss = 0.026, acc = 0.999
# [11] loss = 0.017, acc = 1.000
# [12] loss = 0.012, acc = 1.000
# [13] loss = 0.009, acc = 1.000
# [14] loss = 0.007, acc = 1.000
# [15] loss = 0.006, acc = 1.000
# [16] loss = 0.005, acc = 1.000
# [17] loss = 0.004, acc = 1.000
# [18] loss = 0.003, acc = 1.000
# [19] loss = 0.003, acc = 1.000
# [20] loss = 0.002, acc = 1.000
# [21] loss = 0.002, acc = 1.000
# [22] loss = 0.002, acc = 1.000
# [23] loss = 0.002, acc = 1.000
# [24] loss = 0.001, acc = 1.000
# [25] loss = 0.001, acc = 1.000
# [26] loss = 0.001, acc = 1.000
# [27] loss = 0.001, acc = 1.000
# [28] loss = 0.001, acc = 1.000
# [29] loss = 0.001, acc = 1.000
# [30] loss = 0.001, acc = 1.000

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(hh)
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(acc)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Compare with the PyTorch implementation
#
# Re-implement the ``ParityProblemNetwork`` class using ``torch.nn.LSTM`` instead of ``dlfbt_lab3.LSTM`` and compare the results, both in terms of accuracy and execution time. Include your results, plots and conclusiones in the following cells. It can be a good idea to run the experiments several times to obtain averages.

# %%
### To do: include here your comparison between dlfbt_lab3.LSTM and torch.nn.LSTM.

# %% [markdown]
# ### Many-to-one and many-to-many
#
# The pattern detection problem that we used in exercise 3 is an example of a many-to-one problem, where the input is a sequence and the output is a number (the probability of the sequence containing the pattern). On the other hand, the parity problem that we used in exercise 4 is a many-to-may problem, where both the input and the output are sequences.
#
# Although we used a simple RNN for the first problem and an LSTM for the second, both network architectures can be applied to either problem. Ensure that your implementations of the RNN and the LSTM are general enough to be applicable to the problem for which they were not initially tested. Finally, compare the results obtained with the two network architectures for any of the problems.
#
# Include your tests, results, plots and conclusions in the following cells.

# %%
### To do: include here your comparison between dlfbt_lab3.RNN and dlfbt_lab3.LSTM.
